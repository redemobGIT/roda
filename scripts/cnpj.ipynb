# %%
import basedosdados as bd
from getpass import getpass

# %%
sql = (
    "SELECT * FROM basedosdados.br_me_cnpj.estabelecimentos "
    "WHERE id_municipio = '3304557' "
    "AND data = '2024-11-15' "
)

cnpj = bd.read_sql(
    query=sql,
    billing_project_id=getpass(),
)
# Out:
# Downloading:   2%|▏         |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 7
#       1 sql = (
#       2     "SELECT * FROM basedosdados.br_me_cnpj.estabelecimentos "
#       3     "WHERE id_municipio = '3304557' "
#       4     "AND data = '2024-11-15' "
#       5 )
# ----> 7 cnpj = bd.read_sql(
#       8     query=sql,
#       9     billing_project_id=getpass(),
#      10 )
#
# File c:\Users\brand\anaconda3\envs\roda\Lib\site-packages\basedosdados\download\download.py:97, in read_sql(query, billing_project_id, from_file, reauth, use_bqstorage_api)
#      88 try:
#      89     # Set a two hours timeout
#      90     bigquery_storage_v1.client.BigQueryReadClient.read_rows = (
#      91         partialmethod(
#      92             bigquery_storage_v1.client.BigQueryReadClient.read_rows,
#      93             timeout=3600 * 2,
# ...

# %%
sql = (
    "SELECT * FROM basedosdados.br_me_cnpj.empresas "
    "WHERE data = '2024-11-15' "
    "LIMIT 100 "
)

cnpj = bd.read_sql(
    query=sql,
    billing_project_id=getpass(),
)
# Out:
# Downloading: 100%|██████████|

# %%
cnpj
# Out:
#           data cnpj_basico                                       razao_social  \
# 0   2024-11-15    11434526  CREDIFIBRA S.A. - CREDITO, FINANCIAMENTO E INV...
# 1   2024-11-15    52804798                                   HDT HOLDING S.A.
# 2   2024-11-15    29229029                OENGER S.A. EM RECUPERACAO JUDICIAL
# 3   2024-11-15    17612434                                ADRIANO BRERO LOPES
# 4   2024-11-15    28628198                   SANTOS E BRAGA PARTICIPACOES S/A
# ..         ...         ...                                                ...
# 95  2024-11-15    10307895  COL - CENTRO OESTE LOGISTICA LTDA - EM RECUPER...
# 96  2024-11-15    11417265                   TANIA REGINA TROMBETTA MALACRIDA
# 97  2024-11-15    50516453  FERFEL SERVICOS DE INFORMATICA E CONSULTORIA S/A.
# 98  2024-11-15    11366231                      CENTRAIS EOLICAS DA PRATA S.A
# 99  2024-11-15    02010478        BANCORBRAS ADMINISTRADORA DE CONSORCIOS S.A
#
# ...
