# %% [markdown]
# ## IBEU: Índice de Bem-Estar Urbano
#
# **AUTORIA:** [REDE MOB](https://www.redemob.com.br/)
#
# Este script realiza a estimativa automatizada do Índice de Bem-Estar Urbano (IBEU) para qualquer município brasileiro, a partir de seu código oficial no sistema IBGE. O IBEU é um índice sintético desenvolvido pelo Observatório das Metrópoles, com base em cinco dimensões estruturantes do espaço urbano. A aplicação permite o cálculo tanto para o Censo Demográfico de 2010, via API da Base dos Dados, quanto para os microdados do Censo 2022, via FTP do IBGE.
#
# A partir do processamento e padronização das variáveis relevantes, o script realiza a agregação por setores censitários ou áreas de ponderação, calcula o índice final e produz visualizações cartográficas da distribuição intraurbana do bem-estar no município analisado.
#
# ⚠️ **NOTA METODOLÓGICA**:
# Neste script, duas dimensões do IBEU não serão utilizadas nesta fase:
#
# - Mobilidade Urbana: O principal pilar dessa dimensão é o tempo de deslocamento casa-trabalho. Isso é evidentemente relevante. Contudo, há outros scripts que permitem análises mais abrangentes, incluindo variáveis como (a) pares origem-destino, (b) modos de transporte utilizados (coletivo/individual), e (c) gradientes de acessibilidade no território. Entendemos que isso dá um panorama mais completo da mobilidade e da acessbilidade e é preferível.
#
# - Condições Habitacionais: Esta dimensão se refere à qualidade física das moradias e à densidade de ocupação domiciliar. Como o foco atual é o espaço público urbano, optou-se por excluir temporariamente esta dimensão para privilegiar atributos urbanos nos quais o poder público pode atuar de forma mais direta e estruturante. A abordagem habitacional será tratada em etapa posterior.
#
# **PANORAMA**:
#
# - Coleta automática dos dados censitários de 2010 e 2022 (Base dos Dados e FTP/IBGE)
# - Transposição dos dados censitários para malhas hexagonais H3
# - Cálculo de três das cinco dimensões do IBEU: condições ambientais, infraestrutura e serviços coletivos
# - Agregação e normalização das variáveis segundo a metodologia original
# - Geração de mapas temáticos representando a distribuição espacial do IBEU e de suas dimensões
#
# **MAIS INFORMAÇÕES**:
#
# - Lorem ipsum
#
#
# LINKS DE INTERESSE:
#
# - [Metodologia completa do IBEU – Observatório das Metrópoles](https://ibeu.observatoriodasmetropoles.net.br/wp-content/uploads/2019/05/Indice_de_bem-estar_urbano.pdf)
#
# - Lorem ipsum

# %% [markdown]
# # Instruções para uso do script
#
# Para executar este script corretamente, é necessário fornecer os seguintes parâmetros:
# 1. Código do Município (IBGE)
# - Informe o código numérico do IBGE referente ao município desejado.
# - Para realizar a análise de vários municípios vizinhos, forneça uma lista com os respectivos códigos IBGE.
#
#     🔎 Exemplo: `3304557` (Rio de Janeiro) ou [`3304557`, `3301702`, `3303500`] para múltiplos municípios.
#
# 2. **Ano da Análise**
# - `2010`: dados completos e estruturados para todas as dimensões do IBEU
# - `2022`: dados em atualização, com cobertura variável conforme a dimensão
#
# 3. **Chave de Acesso ao Google Cloud**
# - Para acessar os dados do Censo de 2010 via a plataforma Base dos Dados, é necessário fornecer uma chave de projeto no Google Cloud.
#     - Essa chave permite o uso da API do BigQuery com autenticação segura e serve para o ano de 2010: versões futuras irão resolver essa dependência
#
# 👉 [Obtenha sua chave seguindo o gui elaborado pela equipe da Base dos Dados](https://basedosdados.org/docs/access_data_bq)

# %% [markdown]
# # Parâmetros Definidos Pelo Usuário

# %%
# Backend preliminar
from getpass import getpass

# %%
# código do IBGE da cidade ou de municípios vizinhos
ibge_id = [3303302, 3304904, 3301900] # Niterói, São Gonçalo, Itaboraí
#ibge_id = [3304557]  # Rio de Janeiro

# Ano da Análise
ano = 2022

# Chave do Google Cloud
gcloud_id = getpass("Chave de API do Google Cloud Platform: ")

# %% [markdown]
# # Backend

# %% [markdown]
# ## Bibliotecas e Parâmetros Básicos

# %%
from io import BytesIO
from pathlib import Path
import requests
import tempfile
import zipfile

import contextily as cx
from operator import le
import pandas as pd
import geopandas as gpd
from tobler.area_weighted import area_interpolate
from tobler.util import h3fy

import contextily as ctx
import basedosdados as bd
import geobr
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.legend import Legend
from matplotlib.lines import Line2D
from matplotlib_map_utils.core.north_arrow import north_arrow
from matplotlib_scalebar.scalebar import ScaleBar
import numpy as np
import pandas as pd
import seaborn as sns
from shapely.affinity import scale
from statsmodels.stats.weightstats import DescrStatsW
from tobler.area_weighted import area_interpolate
from tobler.util import h3fy

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use('ggplot')

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Área de Estudo

# %%
def get_census_tracts(ibge_id, year=2010) -> gpd.GeoDataFrame:
    """
    Prepares the study area by fetching census tracts for the given IBGE IDs.

    Parameters:
        ibge_id (int or list[int]): IBGE municipality code(s).
        year (int): Year of the census data (default is 2010).

    Returns:
        gpd.GeoDataFrame: A GeoDataFrame with census tracts, properly formatted.
    """
    if not isinstance(ibge_id, list):
        ibge_id = [ibge_id]

    # Fetch census tracts for each IBGE ID
    tracts = pd.concat(
        [geobr.read_census_tract(int(id_), year=year) for id_ in ibge_id]
    )
    crs = tracts.estimate_utm_crs(datum_name='SIRGAS 2000')

    # Process and format the GeoDataFrame
    tracts = (
        tracts.astype({'code_tract': np.int64})
        .astype({'code_tract': 'str'})
        .rename(columns={'code_tract': 'id_setor_censitario'})
        .set_index('id_setor_censitario')
        .to_crs(crs)
    )

    return tracts.reindex(columns=['geometry'])

# %%
tracts = get_census_tracts(ibge_id)
crs = tracts.estimate_utm_crs(datum_name='SIRGAS 2000')
crs
# Out:
# <Projected CRS: EPSG:31983>
# Name: SIRGAS 2000 / UTM zone 23S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Brazil - between 48°W and 42°W, northern and southern hemispheres, onshore and offshore.
# - bounds: (-48.0, -33.5, -42.0, 5.13)
# Coordinate Operation:
# - name: UTM zone 23S
# - method: Transverse Mercator
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Procedimento de Cálculo

# %% [markdown]
# ### 2010

# %%
# ---------------------------------------------------------------------
# CONSTANTS
# ---------------------------------------------------------------------

# D2: Environmental Conditions
ENVIRONMENT_GROUPS = {
    'arborizacao': ['v044', 'v046', 'v048'],
    'esgoto': ['v051', 'v053', 'v055'],
    'lixo': ['v057', 'v059', 'v061'],
}

# D4: Collective Urban Services
SERVICES_INDICATORS = ['v012', 'v017', 'v035', 'v044']

# D5: Urban Infrastructure
INFRASTRUCTURE_GROUPS = {
    'logradouro': ['v002', 'v004', 'v006'],
    'iluminacao': ['v008', 'v010', 'v012'],
    'pavimentacao': ['v014', 'v016', 'v018'],
    'calcada': ['v020', 'v022', 'v024'],
    'meio_fio': ['v026', 'v028', 'v030'],
    'bueiro': ['v032', 'v034', 'v036'],
    'rampa': ['v038', 'v040', 'v042'],
}

# D2 + D5: para facilitar as queries
SURROUNDINGS_VARS = (
    ['id_setor_censitario', 'v001'] +
    [f'v{v:03}' for v in range(2, 49, 2)] +
    [f'v{v:03}' for v in range(51, 62, 2)]
)


# ---------------------------------------------------------------------
# UTILITIES
# ---------------------------------------------------------------------

def sql_style_list(sequence):
    """Convert a sequence into a SQL-style list of quoted strings."""
    return ", ".join(f"'{item}'" for item in sequence)


def normalize_min_max(df: pd.DataFrame) -> pd.DataFrame:
    """Normalize DataFrame columns to the [0, 1] interval."""
    return (df - df.min()) / (df.max() - df.min())


def interpolate_to_h3(
    gdf: gpd.GeoDataFrame,
    h3_cells: gpd.GeoDataFrame,
    extensive: list[str],
    intensive: list[str] | None = None,
) -> gpd.GeoDataFrame:
    """Interpolates census data into H3 hexagons using Tobler."""
    return area_interpolate(
        source_df=gdf.assign(geometry=lambda x: x.buffer(0)).fillna(0),
        target_df=h3_cells,
        extensive_variables=extensive,
        intensive_variables=intensive or [],
        allocate_total=True,
    )

# ---------------------------------------------------------------------
# DATA FETCHING
# ---------------------------------------------------------------------

def fetch_urban_services(tracts, gcloud_id):
    """Fetch urban services data from Base dos Dados."""
    query = (
        f"SELECT id_setor_censitario, v002, {', '.join(SERVICES_INDICATORS)} "
        "FROM basedosdados.br_ibge_censo_demografico."
        "setor_censitario_domicilio_caracteristicas_gerais_2010 "
        f"WHERE id_setor_censitario IN ({sql_style_list(tracts.index)})"
    )
    df = bd.read_sql(query, billing_project_id=gcloud_id)
    return tracts.merge(df, left_index=True, right_on='id_setor_censitario')


def fetch_surroundings(tracts, gcloud_id):
    """Fetch surroundings data from Base dos Dados."""
    query = (
        f"SELECT {', '.join(SURROUNDINGS_VARS)} "
        "FROM basedosdados.br_ibge_censo_demografico."
        "setor_censitario_entorno_2010 "
        f"WHERE id_setor_censitario IN ({sql_style_list(tracts.index)})"
    )
    df = bd.read_sql(query, billing_project_id=gcloud_id)
    return tracts.merge(df, left_index=True, right_on='id_setor_censitario')


# ---------------------------------------------------------------------
# DIMENSION SCORE COMPUTATION
# ---------------------------------------------------------------------

def compute_env_score_h3(df: pd.DataFrame) -> pd.Series:
    """Compute D2: Environmental Conditions score with explicit 1/3 weights."""
    proportions = {
        'arborizacao': df[ENVIRONMENT_GROUPS['arborizacao']].sum(axis=1) / df['v001'],
        'esgoto': df[ENVIRONMENT_GROUPS['esgoto']].sum(axis=1) / df['v001'],
        'lixo': df[ENVIRONMENT_GROUPS['lixo']].sum(axis=1) / df['v001'],
    }
    normed = normalize_min_max(pd.DataFrame(proportions))
    score = (
        (1/3) * normed['arborizacao'] +
        (1/3) * normed['esgoto'] +
        (1/3) * normed['lixo']
    )
    return score.rename('condicoes_ambientais')


def compute_services_score_h3(df: pd.DataFrame) -> pd.Series:
    """Compute D4: Urban Collective Services score with correct weights."""
    proportions = df[SERVICES_INDICATORS].div(df['v002'], axis=0)
    normed = normalize_min_max(proportions)
    
    # Map columns to their roles
    # You must ensure these names match your actual variable meaning
    score = (
        0.2 * normed['v012'] +  # água
        0.4 * normed['v017'] +  # esgoto
        0.2 * normed['v035'] +  # energia
        0.2 * normed['v044']    # lixo
    )
    return score.rename('servicos_coletivos')


def compute_infra_score_h3(df: pd.DataFrame) -> pd.Series:
    """Compute D5: Urban Infrastructure score with explicit 1/7 weights."""
    proportions = {
        key: df[cols].sum(axis=1) / df['v001']
        for key, cols in INFRASTRUCTURE_GROUPS.items()
    }
    normed = normalize_min_max(pd.DataFrame(proportions))
    score = sum((1/7) * normed[col] for col in normed.columns)
    return score.rename('infraestrutura_urbana')


# ---------------------------------------------------------------------
# MAIN FUNCTION
# ---------------------------------------------------------------------

def compute_ibeu_h3(
    gdf_surroundings: gpd.GeoDataFrame,
    gdf_services: gpd.GeoDataFrame,
    resolution: int = 9,
) -> pd.DataFrame:
    """
    Compute IBEU scores (D2, D4, D5) per H3 hexagon.

    Parameters
    ----------
    gdf_surroundings : GeoDataFrame
        Census data with infrastructure/environment variables (D2, D5).
    gdf_services : GeoDataFrame
        Census data with collective service variables (D4).
    resolution : int
        H3 resolution level (default: 8).

    Returns
    -------
    pd.DataFrame
        DataFrame with IBEU dimension scores and final IBEU per hex.
    """
    sur_vars = (
        ['v001'] +
        [f'v{v:03}' for v in range(2, 49, 2)] +
        [f'v{v:03}' for v in range(51, 62, 2)]
    )
    serv_vars = ['v002'] + SERVICES_INDICATORS

    h3_cells = h3fy(tracts.buffer(50), resolution=resolution)
    h3_sur = interpolate_to_h3(gdf_surroundings, h3_cells, sur_vars)
    h3_serv = interpolate_to_h3(gdf_services, h3_cells, serv_vars)

    scores = pd.concat([
        compute_env_score_h3(h3_sur),
        compute_services_score_h3(h3_serv),
        compute_infra_score_h3(h3_sur)
    ], axis=1)

    scores['ibeu'] = scores.mean(axis=1)
    return h3_cells.merge(scores, left_index=True, right_index=True)

# %%
gdf_surroundings=fetch_surroundings(tracts, gcloud_id)
gdf_services=fetch_urban_services(tracts, gcloud_id)
# Out:
# Downloading: 100%|██████████|
# Downloading: 100%|██████████|

# %%
ibeu = compute_ibeu_h3(
    gdf_surroundings,
    gdf_services,
)

# %%
ibeu.explore('ibeu', cmap='RdYlBu',scheme='UserDefined', classification_kwds={
    'bins': [.5, .700, 0.8, 0.9, 1],
    #'labels': ['Muito Ruim', 'Ruim', 'Médio', 'Bom', 'Muito Bom'],
})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## 2022

# %%
BASE = ('https://ftp.ibge.gov.br/Censos/Censo_Demografico_2022/'
        'Agregados_por_Setores_Censitarios_Caracteristicas_urbanisticas_do_entorno_dos_domicilios/'
        'Agregados_por_Setor_csv/'
    )
PATH_TO_SURROUNDINGS = f"{BASE}/Agregados_por_setores_entorno_moradores_BR.zip"
surroundings = (
    pd
    .read_csv(PATH_TO_SURROUNDINGS, sep=';')
    .astype({'CD_setor': str})
    .set_index('CD_setor')
    .rename_axis('id_setor_censitario')
    )


BASE = ('https://ftp.ibge.gov.br/Censos/Censo_Demografico_2022/'
        'Agregados_por_Setores_Censitarios/Agregados_por_Setor_csv/'
    )

household_batches = []
for i in range(1, 4):
    suffix = '' if i == 1 else '_20250417'
    PATH_TO_HOUSEHOLDS = f"{BASE}/Agregados_por_setores_caracteristicas_domicilio{i}_BR{suffix}.zip"

    print(PATH_TO_HOUSEHOLDS)

    household_batches.append(
        pd
        .read_csv(PATH_TO_HOUSEHOLDS, sep=';')
        .set_index('CD_setor' if i == 1 else 'setor')
        )
    
households = (
    pd
    .concat(household_batches, axis='columns')
    .rename_axis('id_setor_censitario')
    )
households.index = households.index.astype(str)
# Out:
# https://ftp.ibge.gov.br/Censos/Censo_Demografico_2022/Agregados_por_Setores_Censitarios/Agregados_por_Setor_csv//Agregados_por_setores_caracteristicas_domicilio1_BR.zip
# https://ftp.ibge.gov.br/Censos/Censo_Demografico_2022/Agregados_por_Setores_Censitarios/Agregados_por_Setor_csv//Agregados_por_setores_caracteristicas_domicilio2_BR_20250417.zip
# https://ftp.ibge.gov.br/Censos/Censo_Demografico_2022/Agregados_por_Setores_Censitarios/Agregados_por_Setor_csv//Agregados_por_setores_caracteristicas_domicilio3_BR_20250417.zip

# %%
tracts = get_census_tracts(ibge_id, year=2022)
crs = tracts.estimate_utm_crs(datum_name='SIRGAS 2000')
tracts = tracts.to_crs(crs)

# %%
db = tracts.reindex(columns=['geometry']).merge(
    surroundings,
    left_index=True,
    right_index=True
).merge(
    households,
    left_index=True,
    right_index=True
).replace({'X': 0})

# %%
db['people'] = db.V05200.astype(int)
db['has_sewage'] = db[['V00580', 'V00581']].astype(int).sum(axis=1)
db['has_garbage_collection'] = db[['V00612', 'V00613']].astype(int).sum(axis=1)
db['has_water'] = db[['V00508']].astype(int)

db['has_pavement'] = db.V05206.astype(int)
db['has_trees'] = db.people - db.V05230.astype(int)
db['has_sidewalk'] = db.V05221.astype(int)
db['has_lamppost'] = db.V05212.astype(int)
db['has_gutter'] = db.V05209.astype(int)
db['has_ramp'] = db.V05227.astype(int)
db['has_obstacle'] = db.V05224.astype(int)

db = db.loc[:, ~db.columns.str.startswith('V')]

# %%
def compute_env_score_2022(df: pd.DataFrame) -> pd.Series:
    """Compute D2: Environmental Conditions 2022 (trees only)."""
    proportions = df['has_trees'] / df['people']
    normed = normalize_min_max(proportions)
    return normed.rename('condicoes_ambientais')


def compute_services_score_2022(df: pd.DataFrame) -> pd.Series:
    """Compute D4: Urban Collective Services 2022 (water, sewage, garbage)."""
    proportions = pd.DataFrame({
        'water': df['has_water'] / df['people'],
        'sewage': df['has_sewage'] / df['people'],
        'garbage': df['has_garbage_collection'] / df['people'],
    })
    normed = normalize_min_max(proportions)
    score = (
        (1/3) * normed['water'] +
        (1/3) * normed['sewage'] +
        (1/3) * normed['garbage']
    )
    return score.rename('servicos_coletivos')


def compute_infra_score_2022(df: pd.DataFrame) -> pd.Series:
    """Compute D5: Urban infrastructure 2022 with sidewalk obstacle."""
    proportions = pd.DataFrame({
        'lamp': df['has_lamppost'] / df['people'],
        'pavement': df['has_pavement'] / df['people'],
        'sidewalk': df['has_sidewalk'] / df['people'],
        'gutter': df['has_gutter'] / df['people'],
        'ramp': df['has_ramp'] / df['people'],
        'no_obstacle': 1 - (df['has_obstacle'] / df['people'])
    })
    normed = normalize_min_max(proportions)
    N = len(normed.columns)
    score = sum((1/N) * normed[col] for col in normed.columns)
    return score.rename('infraestrutura_urbana')

# %%
scores = pd.concat([
    #compute_env_score_2022(db),
    compute_services_score_2022(db),
    compute_infra_score_2022(db)
], axis=1)

scores['ibeu2022'] = scores.mean(axis=1)

# %% [markdown]
# # Visualizações

# %%
def _add_north(ax):
    north_arrow(
        ax,
        location="upper left",
        rotation={"crs": ibeu.crs, "reference": "center"}
    )

def _add_basemap(ax):
    try:
        cx.add_basemap(
            ax,
            source=cx.providers.CartoDB.Positron,
            crs=31983,
            attribution_size=12,
            )
        txt = ax.texts[-1]
        txt.set_position([0.99, 0.02])
        txt.set_ha('right')
        txt.set_va('bottom')
    except:
        pass


def _map_embelishments(ax):
    _add_north(ax)
    _add_basemap(ax)    
    ax.add_artist(
        ScaleBar(1, location='lower left', font_properties={"size": 18})
        )
    ax.axis('off')

# %%
f, ax = plt.subplots(figsize=(20, 10))

legend_kwds={
'bbox_to_anchor': (1, 1),
'loc': 'upper left',
'fontsize': 17,
'title': 'IBEU',
'title_fontsize': 18,
'fmt': '{:,.1f}',
'frameon': False,
'ncol': 1,
#'markerscale': 2,
'interval': True,
}

ibeu.plot(
    ax=ax,
    column='ibeu',
    cmap='RdYlBu',
    scheme='UserDefined',
    classification_kwds={
        'bins': [.5, .7, .8, .9, 1],
        },
    antialiased=False,
    linewidth=0,
    alpha=.75,
    legend=True,
    legend_kwds=legend_kwds,
    )

ax.set_axis_off()

_map_embelishments(ax)

plt.savefig(
    Path('ibeu_map.png'),
    bbox_inches='tight',
    dpi=600,
)

plt.show()

# %%
ibeu.to_parquet('ibeu.parquet')

# %% [markdown]
# # Exercício: Mapas Coropléticos

# %% [markdown]
# Objetivo: Compreender os princípios básicos do mapeamento coroplético e aplicar técnicas de classificação e escolha de cores para representar dados espaciais.
#
# Contexto:
#
# Mapas coropléticos são representações cartográficas que utilizam variações de cor para mostrar valores estatísticos agregados por regiões (como estados, municípios ou bairros). Cada região é associada a um valor e preenchida com uma cor que corresponde à sua classe de valor. Embora hoje seja possível criar mapas sem classificação (unclassed), a abordagem com classes (classed) continua sendo valiosa por facilitar a interpretação visual dos dados.
#
# Três decisões fundamentais no mapeamento coroplético:
# - Número de classes: Definir em quantos grupos os valores serão divididos.
# - Método de classificação: Escolher o algoritmo para agrupar os dados (ex: quantis, intervalos iguais, Jenks).
# - Escolha das cores: Aplicar uma paleta que represente adequadamente as diferenças entre os grupos.
#
# Você deve explorar esses conceitos e, para isso, irá utilizar bibliotecas Python como geopandas e [pacotes do conjunto de bibliotecas PySAL](https://pysal.org/). Acompanhe o capítulo Choropleth Mapping do livro [Geographic Data Science with Python](https://geographicdata.science/book/notebooks/05_choropleth.html) e reproduza o exercício prático lá contido com os municípios acima. Documente o passo a passo e discuta e analise seus achados.
