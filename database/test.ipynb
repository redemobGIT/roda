# %%
r5py.cache_clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 r5py.cache_clear()
#
# AttributeError: module 'r5py' has no attribute 'cache_clear'
